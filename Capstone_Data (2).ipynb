# %% [markdown]
# # Data Prep Stage for migration patterns of top 5 inbound states

# %% [markdown]
# This is the first stage where we will upload the data. Once its done, we will be playing with data to make it more meaningful and accurate for the data visualization for furthur analysis.
#
# This data corresponds to top five states for inbound migration from 2010-2020.
#
# Note: Data from https://www.census.gov/data/tables/time-series/demo/popest/2010s-state-total.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Top Five cities

# %% [markdown]
# Once we know the top state where the maximum Inbound migration is taking place , we will explore the top 5 cities in that state. Based upon the results we will explore the city that is on the lower side of the real estate listed pricing .
#
# Since we know real estate plays a major role when any migration takes place. The changes in migration patterns comes along with opportunities and risks. After some research done using google tool, the data that came up for top 5 cities and its real estate average listed pricing . The data will be like this : ![image.png](attachment:image.png)

# %% [markdown]
# In the next step, we will be studing the city with its lat lang coordinates.  ![image.png](attachment:image.png) and analyse the city with other features like population , race, age, and other demographic details, so that this report can become a tool for the Real estate investors.
